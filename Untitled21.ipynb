# %% [markdown]
# <a href="https://colab.research.google.com/github/saadqaqa-etu/Credit-Card-Fraud-Detection-using-Autoencoders-in-Keras/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %%
df = pd.read_csv("/content/drive/MyDrive/creditcard (1).csv")

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().values.any()
# Out:
# False

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]

# %%
frauds.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %%
frauds.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

data = df.drop(['Time'], axis=1)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

# %%
X_train.shape
# Out:
# (227451, 29)

# %%
input_dim = X_train.shape[1]
encoding_dim = 14

# %%
input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="tanh",
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)

decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
nb_epoch = 100
batch_size = 32

autoencoder.compile(optimizer='adam',
                    loss='mean_squared_error',
                    metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
# 7108/7108 [==============================] - 19s 2ms/step - loss: 0.8115 - accuracy: 0.5803 - val_loss: 0.7889 - val_accuracy: 0.6242
# Epoch 2/100
#   87/7108 [..............................] - ETA: 12s - loss: 1.4070 - accuracy: 0.6225
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7464 - accuracy: 0.6382 - val_loss: 0.7687 - val_accuracy: 0.6575
# Epoch 3/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7333 - accuracy: 0.6599 - val_loss: 0.7624 - val_accuracy: 0.6638
# Epoch 4/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7280 - accuracy: 0.6649 - val_loss: 0.7593 - val_accuracy: 0.6613
# Epoch 5/100
# 7108/7108 [==============================] - 25s 4ms/step - loss: 0.7240 - accuracy: 0.6695 - val_loss: 0.7549 - val_accuracy: 0.6742
# Epoch 6/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7213 - accuracy: 0.6758 - val_loss: 0.7537 - val_accuracy: 0.6789
# Epoch 7/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7187 - accuracy: 0.6811 - val_loss: 0.7489 - val_accuracy: 0.6853
# Epoch 8/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7160 - accuracy: 0.6849 - val_loss: 0.7471 - val_accuracy: 0.6836
# Epoch 9/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7128 - accuracy: 0.6847 - val_loss: 0.7446 - val_accuracy: 0.6908
# Epoch 10/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7120 - accuracy: 0.6851 - val_loss: 0.7438 - val_accuracy: 0.6910
# Epoch 11/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7106 - accuracy: 0.6860 - val_loss: 0.7463 - val_accuracy: 0.6862
# Epoch 12/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7099 - accuracy: 0.6868 - val_loss: 0.7413 - val_accuracy: 0.6918
# Epoch 13/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7093 - accuracy: 0.6890 - val_loss: 0.7427 - val_accuracy: 0.6824
# Epoch 14/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7086 - accuracy: 0.6897 - val_loss: 0.7409 - val_accuracy: 0.6952
# Epoch 15/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7079 - accuracy: 0.6895 - val_loss: 0.7392 - val_accuracy: 0.6941
# Epoch 16/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7071 - accuracy: 0.6907 - val_loss: 0.7414 - val_accuracy: 0.6922
# Epoch 17/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7057 - accuracy: 0.6926 - val_loss: 0.7394 - val_accuracy: 0.6981
# Epoch 18/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7053 - accuracy: 0.6933 - val_loss: 0.7376 - val_accuracy: 0.6969
# Epoch 19/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7050 - accuracy: 0.6933 - val_loss: 0.7391 - val_accuracy: 0.6915
# Epoch 20/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7046 - accuracy: 0.6932 - val_loss: 0.7376 - val_accuracy: 0.6963
# Epoch 21/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7040 - accuracy: 0.6944 - val_loss: 0.7357 - val_accuracy: 0.6943
# Epoch 22/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7037 - accuracy: 0.6940 - val_loss: 0.7355 - val_accuracy: 0.6984
# Epoch 23/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7029 - accuracy: 0.6952 - val_loss: 0.7349 - val_accuracy: 0.6948
# Epoch 24/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7026 - accuracy: 0.6961 - val_loss: 0.7342 - val_accuracy: 0.6915
# Epoch 25/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7024 - accuracy: 0.6966 - val_loss: 0.7387 - val_accuracy: 0.6977
# Epoch 26/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7023 - accuracy: 0.6981 - val_loss: 0.7343 - val_accuracy: 0.6962
# Epoch 27/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7017 - accuracy: 0.6997 - val_loss: 0.7345 - val_accuracy: 0.6967
# Epoch 28/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7014 - accuracy: 0.7000 - val_loss: 0.7341 - val_accuracy: 0.7011
# Epoch 29/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7011 - accuracy: 0.7009 - val_loss: 0.7343 - val_accuracy: 0.7050
# Epoch 30/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7007 - accuracy: 0.7025 - val_loss: 0.7340 - val_accuracy: 0.7041
# Epoch 31/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7007 - accuracy: 0.7032 - val_loss: 0.7355 - val_accuracy: 0.6997
# Epoch 32/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7004 - accuracy: 0.7044 - val_loss: 0.7345 - val_accuracy: 0.6990
# Epoch 33/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.7002 - accuracy: 0.7045 - val_loss: 0.7324 - val_accuracy: 0.7075
# Epoch 34/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6997 - accuracy: 0.7050 - val_loss: 0.7331 - val_accuracy: 0.7085
# Epoch 35/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6997 - accuracy: 0.7055 - val_loss: 0.7334 - val_accuracy: 0.7020
# Epoch 36/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6994 - accuracy: 0.7064 - val_loss: 0.7347 - val_accuracy: 0.7085
# Epoch 37/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6993 - accuracy: 0.7050 - val_loss: 0.7318 - val_accuracy: 0.7062
# Epoch 38/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6994 - accuracy: 0.7069 - val_loss: 0.7338 - val_accuracy: 0.7025
# Epoch 39/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6990 - accuracy: 0.7061 - val_loss: 0.7317 - val_accuracy: 0.7102
# Epoch 40/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.6992 - accuracy: 0.7067 - val_loss: 0.7324 - val_accuracy: 0.7122
# Epoch 41/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6989 - accuracy: 0.7066 - val_loss: 0.7405 - val_accuracy: 0.7008
# Epoch 42/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6988 - accuracy: 0.7073 - val_loss: 0.7322 - val_accuracy: 0.7080
# Epoch 43/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6989 - accuracy: 0.7066 - val_loss: 0.7322 - val_accuracy: 0.7059
# Epoch 44/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6986 - accuracy: 0.7068 - val_loss: 0.7329 - val_accuracy: 0.7058
# Epoch 45/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6984 - accuracy: 0.7068 - val_loss: 0.7313 - val_accuracy: 0.7124
# Epoch 46/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6981 - accuracy: 0.7070 - val_loss: 0.7308 - val_accuracy: 0.7127
# Epoch 47/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.6984 - accuracy: 0.7080 - val_loss: 0.7323 - val_accuracy: 0.7096
# Epoch 48/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6982 - accuracy: 0.7071 - val_loss: 0.7314 - val_accuracy: 0.7153
# Epoch 49/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6980 - accuracy: 0.7081 - val_loss: 0.7306 - val_accuracy: 0.7145
# Epoch 50/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6982 - accuracy: 0.7079 - val_loss: 0.7302 - val_accuracy: 0.7132
# Epoch 51/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6981 - accuracy: 0.7084 - val_loss: 0.7339 - val_accuracy: 0.7081
# Epoch 52/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6980 - accuracy: 0.7087 - val_loss: 0.7316 - val_accuracy: 0.7119
# Epoch 53/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6979 - accuracy: 0.7076 - val_loss: 0.7309 - val_accuracy: 0.7113
# Epoch 54/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6978 - accuracy: 0.7084 - val_loss: 0.7334 - val_accuracy: 0.7130
# Epoch 55/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.6977 - accuracy: 0.7085 - val_loss: 0.7309 - val_accuracy: 0.7116
# Epoch 56/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6982 - accuracy: 0.7079 - val_loss: 0.7300 - val_accuracy: 0.7116
# Epoch 57/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.6979 - accuracy: 0.7089 - val_loss: 0.7312 - val_accuracy: 0.7121
# Epoch 58/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6976 - accuracy: 0.7085 - val_loss: 0.7310 - val_accuracy: 0.7116
# Epoch 59/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6976 - accuracy: 0.7088 - val_loss: 0.7314 - val_accuracy: 0.7156
# Epoch 60/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.6977 - accuracy: 0.7092 - val_loss: 0.7321 - val_accuracy: 0.7107
# Epoch 61/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.6978 - accuracy: 0.7095 - val_loss: 0.7355 - val_accuracy: 0.7024
# Epoch 62/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6982 - accuracy: 0.7092 - val_loss: 0.7320 - val_accuracy: 0.7116
# Epoch 63/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.6978 - accuracy: 0.7093 - val_loss: 0.7304 - val_accuracy: 0.7138
# Epoch 64/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.6976 - accuracy: 0.7091 - val_loss: 0.7325 - val_accuracy: 0.7141
# Epoch 65/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6973 - accuracy: 0.7103 - val_loss: 0.7321 - val_accuracy: 0.7165
# Epoch 66/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6974 - accuracy: 0.7099 - val_loss: 0.7302 - val_accuracy: 0.7153
# Epoch 67/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6975 - accuracy: 0.7093 - val_loss: 0.7331 - val_accuracy: 0.7067
# Epoch 68/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6973 - accuracy: 0.7104 - val_loss: 0.7307 - val_accuracy: 0.7122
# Epoch 69/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6972 - accuracy: 0.7104 - val_loss: 0.7326 - val_accuracy: 0.7058
# Epoch 70/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6972 - accuracy: 0.7100 - val_loss: 0.7327 - val_accuracy: 0.7053
# Epoch 71/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6971 - accuracy: 0.7106 - val_loss: 0.7309 - val_accuracy: 0.7135
# Epoch 72/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6972 - accuracy: 0.7116 - val_loss: 0.7310 - val_accuracy: 0.7141
# Epoch 73/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6971 - accuracy: 0.7121 - val_loss: 0.7297 - val_accuracy: 0.7135
# Epoch 74/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6970 - accuracy: 0.7118 - val_loss: 0.7299 - val_accuracy: 0.7181
# Epoch 75/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6967 - accuracy: 0.7130 - val_loss: 0.7341 - val_accuracy: 0.7106
# Epoch 76/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6971 - accuracy: 0.7127 - val_loss: 0.7331 - val_accuracy: 0.7099
# Epoch 77/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6968 - accuracy: 0.7137 - val_loss: 0.7301 - val_accuracy: 0.7131
# Epoch 78/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6965 - accuracy: 0.7135 - val_loss: 0.7303 - val_accuracy: 0.7187
# Epoch 79/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6964 - accuracy: 0.7132 - val_loss: 0.7288 - val_accuracy: 0.7173
# Epoch 80/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6966 - accuracy: 0.7134 - val_loss: 0.7311 - val_accuracy: 0.7148
# Epoch 81/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6961 - accuracy: 0.7119 - val_loss: 0.7301 - val_accuracy: 0.7177
# Epoch 82/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6963 - accuracy: 0.7128 - val_loss: 0.7302 - val_accuracy: 0.7163
# Epoch 83/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6960 - accuracy: 0.7135 - val_loss: 0.7292 - val_accuracy: 0.7198
# Epoch 84/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6958 - accuracy: 0.7117 - val_loss: 0.7306 - val_accuracy: 0.7060
# Epoch 85/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6956 - accuracy: 0.7120 - val_loss: 0.7336 - val_accuracy: 0.7078
# Epoch 86/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6955 - accuracy: 0.7118 - val_loss: 0.7288 - val_accuracy: 0.7133
# Epoch 87/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6952 - accuracy: 0.7112 - val_loss: 0.7323 - val_accuracy: 0.7109
# Epoch 88/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.6954 - accuracy: 0.7116 - val_loss: 0.7301 - val_accuracy: 0.7142
# Epoch 89/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6951 - accuracy: 0.7125 - val_loss: 0.7295 - val_accuracy: 0.7161
# Epoch 90/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.6953 - accuracy: 0.7119 - val_loss: 0.7309 - val_accuracy: 0.7086
# Epoch 91/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.6952 - accuracy: 0.7118 - val_loss: 0.7305 - val_accuracy: 0.7085
# Epoch 92/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6955 - accuracy: 0.7122 - val_loss: 0.7310 - val_accuracy: 0.7084
# Epoch 93/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.6956 - accuracy: 0.7106 - val_loss: 0.7285 - val_accuracy: 0.7105
# Epoch 94/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.6949 - accuracy: 0.7124 - val_loss: 0.7292 - val_accuracy: 0.7125
# Epoch 95/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6953 - accuracy: 0.7122 - val_loss: 0.7284 - val_accuracy: 0.7161
# Epoch 96/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.6953 - accuracy: 0.7129 - val_loss: 0.7282 - val_accuracy: 0.7141
# Epoch 97/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6950 - accuracy: 0.7121 - val_loss: 0.7271 - val_accuracy: 0.7147
# Epoch 98/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6952 - accuracy: 0.7126 - val_loss: 0.7284 - val_accuracy: 0.7139
# Epoch 99/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6945 - accuracy: 0.7131 - val_loss: 0.7280 - val_accuracy: 0.7163
# Epoch 100/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.6954 - accuracy: 0.7119 - val_loss: 0.7425 - val_accuracy: 0.6982

# %%
autoencoder = load_model('model.h5')

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)
# Out:
# 1781/1781 [==============================] - 3s 1ms/step

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.726096      0.001720
# std                3.413803      0.041443
# min                0.028462      0.000000
# 25%                0.233703      0.000000
# 50%                0.388528      0.000000
# 75%                0.620196      0.000000
# max              260.315692      1.000000

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %%
threshold = 2.9

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
